# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
emp_data = pd.read_excel('./datasets/Absenteeism_at_work_Project.xls')

# %%
emp_data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                26.0               7.0                3        1
# 1  36                 0.0               7.0                3        1
# 2   3                23.0               7.0                4        1
# 3   7                 7.0               7.0                5        1
# 4  11                23.0               7.0                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                   289.0                             36.0          13.0
# 1                   118.0                             13.0          18.0
# 2                   179.0                             51.0          18.0
# 3                   279.0                              5.0          14.0
# 4                   289.0                             36.0          13.0
#
#     Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
emp_data.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          737.000000        739.000000       740.000000
# mean    18.017568           19.188602          6.319350         3.914865
# std     11.021247            8.437493          3.435948         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              733.000000                       737.000000
# mean     2.544595              221.035471                        29.667571
# std      1.111831               66.954179                        14.848124
# ...

# %%
plt.subplots(figsize=(12,6))


sns.distplot(emp_data['Reason for absence'], bins= 29, kde= False, rug = True)
plt.show()

# %%
plt.subplots(figsize=(12,6))


sns.distplot(emp_data['Month of absence'], bins= 12, kde= False, rug = True)
plt.show()

# %%
sns.jointplot(x= "Day of the week", y= "Reason for absence",
             data = emp_data, height = 6)
plt.show()

# %%
pairplot = sns.pairplot(emp_data, 
                          height = 4, 
                          aspect = 1,
                          x_vars = ["Distance from Residence to Work",
                                "Body mass index",
                                "Age"],
                        
                          y_vars = ["Absenteeism time in hours",
                                "Work load Average/day "],
                          kind = "reg",
                          hue = "Disciplinary failure"
        )
    
pairplot.fig.subplots_adjust(wspace = 0.5, hspace = 0.1)
    
plt.show()

# %%
poll_data = pd.read_csv('datasets/pollution_data.csv')

# %%
poll_data = poll_data[:1000]

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': 'white',
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.projecting: 'projecting'>,
#  'patch.edgecolor': 'black',
#  'patch.force_edgecolor': False,
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
# ...

# %%
sns.distplot(poll_data["NO2 AQI"])
plt.show()

# %%
sns.set_style("whitegrid", {
                            "axes.facecolor" : "white",
                            "axes.edgecolor" : "black",
                            "axes.labelcolor" : "green",
                            "gird.color" : "#000000",
                            "font.family" : "fantasy",
                            "grid.linestyle" : "-.",
                            "axes.spines.top" :  False,
                            "axes.spines.right" : False,})
sns.distplot(poll_data["NO2 AQI"], color = "maroon")

plt.show()

# %%
sns.set()

# %%
sns.set_context("talk")
sns.distplot(poll_data["NO2 AQI"])
plt.show()

# %%
sns.set_context("paper")
sns.distplot(poll_data["NO2 AQI"])
plt.show()

# %%
sns.set_context("poster")
sns.distplot(poll_data["NO2 AQI"])
plt.show()

# %%
sns.set_context("notebook",
                font_scale = 1.0,
                rc = {"lines.linewidth" : 2} )
sns.distplot(poll_data["NO2 AQI"])
plt.show()

# %%
car_data = pd.read_csv('datasets/auto-mpg.csv')

# %%
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
len(car_data.index)
# Out:
# 398

# %%
##box plot

plt.subplots(figsize = (12,6)) 
sns.boxplot(y = "mpg", x = "cylinders", data = car_data) 
plt.show()

# %%
plt.subplots(figsize = (12,6)) 

sns.violinplot(x="cylinders", 
            y = "mpg", 
            data = car_data)

plt.show()

# %%
plt.subplots(figsize = (12,6)) 

sns.violinplot(x="cylinders", 
            y = "mpg", 
            data = car_data,
              bw = 0.5,
              scale = "count")

plt.show()

# %%
plt.subplots(figsize = (12,6)) 

sns.violinplot(x="cylinders", 
            y = "mpg", 
            data = car_data,
               inner = "stick",
              bw = 0.5,
              scale = "count",
              palette = "rainbow")

plt.show()

# %%
plt.subplots(figsize = (12,6)) 

sns.violinplot(x="cylinders", 
            y = "mpg", 
            data = car_data,
               inner = None)

sns.swarmplot(x="cylinders", 
            y = "mpg", 
            data = car_data,
              color = "black",
              size = 3)

plt.show()

# %%
sns.set(style = "whitegrid",
       color_codes = True)

# %%
plt.subplots(figsize = (12,6)) 
sns.stripplot(x="cylinders", y="mpg", data = car_data, size = 6)
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.stripplot(x="cylinders", y="mpg", data = car_data, size = 6, jitter = True)
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.stripplot(x="cylinders", y="mpg", data = car_data, hue = "model year")
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.barplot(x="cylinders", y="mpg", data = car_data, hue = "model year")
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.countplot(x="origin", data = car_data, palette = "Accent")
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.pointplot(x="cylinders", y="mpg", data = car_data, hue = "model year")
plt.show()

# %%
plt.subplots(figsize = (12,6)) 
sns.catplot(x="cylinders", y="mpg", row="origin", kind = "box", data = car_data, height = 6, aspect = 2)
plt.show()

# %%
##if dataset contain categorial data

zomato_data = pd.read_csv('datasets/zomato.csv', encoding='latin-1')

# %%
zomato_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
zomato_data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
facet = sns.FacetGrid(data = zomato_data, col = "Price range")
plt.show()

# %%
facet.map(plt.hist, "Aggregate rating")
plt.show()

# %%
facet.map(plt.scatter, "Aggregate rating", "Votes", color = "0.3")
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data, col = "Price range", hue = "Currency")
facet.map(plt.scatter, "Aggregate rating", "Votes", alpha = 0.5)

facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data, row ="Has Online delivery", col = "Price range", hue = "Currency",
                     margin_titles= True)
facet.map(plt.scatter, "Aggregate rating", "Votes", alpha = 0.5,)  #fit_reg = False)

facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data, row ="Has Online delivery", col = "Price range", hue = "Currency",
                     margin_titles= True, gridspec_kws = dict(width_ratios = [2,3,5,3]))
facet.map(plt.scatter, "Aggregate rating", "Votes", alpha = 0.5,)  #fit_reg = False)

facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data,col = "Currency")
                    
facet.map(sns.barplot, "Aggregate rating","Average Cost for two")

plt.ylim(0,2000)
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data,col = "Currency", col_wrap = 3)
                    
facet.map(sns.barplot, "Aggregate rating","Average Cost for two")

plt.ylim(0,2000)
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data,col = "Currency", col_wrap = 3, aspect = 1.5)
                    
facet.map(sns.barplot, "Aggregate rating","Average Cost for two", color = '#826EDF')

plt.ylim(0,2000)
plt.show()

# %%
facet = sns.FacetGrid(data = zomato_data,col = "Currency", col_wrap = 3, aspect = 1.5)
                    
facet.map(sns.barplot, "Aggregate rating","Average Cost for two", color = '#826EDF')

facet.fig.subplots_adjust(wspace = 0.5, hspace = 0.5)
facet.set_axis_labels("Rating", "Cost for Two")

plt.ylim(0,2000)
plt.show()

# %%
poll_data = pd.read_csv('datasets/pollution_data.csv')
poll_data = poll_data[:1000]

poll_data.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 1  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# ...

# %%
sns.set_palette("Set1")
fig, axis = plt.subplots(figsize = (10,5))

sns.distplot(poll_data["SO2 1st Max Hour"])
sns.distplot(poll_data["CO 1st Max Hour"])

plt.show()

# %%
with sns.color_palette("Accent"):
        fig, axis = plt.subplots(figsize = (10,5))
        
        sns.distplot(poll_data["SO2 1st Max Hour"])
        sns.distplot(poll_data["CO 1st Max Hour"])
plt.show()

# %%
sns.set()

current_palette = sns.color_palette()

sns.palplot(current_palette)

plt.show()

# %%
hist = plt.subplots(figsize = (12,6))

with plt.rc_context(sns.plotting_context("notebook", font_scale = 1.5, rc = {"lines.linewidth" : 2})):
    sns.kdeplot(poll_data["NO2 AQI"])
    sns.kdeplot(poll_data["NO2 AQI"], bw= 0.3, label = "bw:0.3" )
    sns.kdeplot(poll_data["NO2 AQI"], bw= 10, label = "bw:10" )
    sns.kdeplot(poll_data["NO2 AQI"], bw= 14, label = "bw:14" )
    sns.kdeplot(poll_data["NO2 AQI"], bw= 38, label = "bw:38" )
    
plt.legend()
plt.show()

# %%
spec_num_color_palette = sns.palplot(sns.color_palette("hls", 8))
plt.show()

# %%
spec_num_color_palette = sns.palplot(sns.color_palette("hls", 12))
plt.show()

# %%
spec_num_color_palette = sns.palplot(sns.hls_palette(8, l = 0.3, s= 0.8))
plt.show()

# %%
spec_num_color_palette = sns.palplot(sns.color_palette("viridis"))
plt.show()

# %%
poll_mean = poll_data[['NO2 Mean', 'CO Mean', 'SO2 Mean', 'O3 Mean']]

# %%
corrmatrix = poll_mean.corr()

plt.subplots(figsize = (7,7))
sns.heatmap(corrmatrix, vmax = 0.8, square = True, annot = True, fmt = ".2f", cmap = "viridis")

plt.show()
